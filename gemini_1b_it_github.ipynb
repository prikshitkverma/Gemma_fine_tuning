# %%
# 1. INSTALL LIBRARIES
# --------------------
# Install necessary Hugging Face libraries for training and datasets.
# !pip install -q -U torch tensorboard
# !pip install -q -U transformers datasets accelerate evaluate trl sentencepiece

# 2. SETUP AND AUTHENTICATION
# ---------------------------
import torch
import os
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, pipeline
from trl import SFTTrainer, SFTConfig
from huggingface_hub import login
from google.colab import userdata # Use this if you're storing the token as a Colab secret

# Login to Hugging Face Hub to access the model
# IMPORTANT: Replace with your actual Hugging Face token
# You can get a token here: https://huggingface.co/settings/tokens
HF_TOKEN = "Enter HF Token Here"
login(token=HF_TOKEN)

# 3. CONFIGURE MODEL AND DIRECTORIES
# ----------------------------------
# Define the base model to fine-tune and the directory to save the new model.
base_model = "google/gemma-3-1b-it"
output_dir = "./gemma-natural-farming-qa" # This will be the name of your fine-tuned model

# 4. LOAD AND PREPARE THE DATASET
# -------------------------------
# The path to your local JSONL file
data_file = "/content/nf_dataset_augmented.jsonl"

# Load the dataset from your file
dataset = load_dataset("json", data_files=data_file, split="train")

# Define a function to format your data into the required conversational format.
# The Gemma instruction-tuned model expects a specific chat structure.
def format_dataset(sample):
  """
  Converts a sample from {"question": "...", "answer": "..."} format
  to the required conversational format {"messages": [{"role": "user", ...}, {"role": "assistant", ...}]}.
  """
  return {
      "messages": [
          {"role": "user", "content": sample["question"]},
          {"role": "assistant", "content": sample["answer"]}
      ]
  }

# Apply the formatting function to the entire dataset
formatted_dataset = dataset.map(format_dataset, remove_columns=dataset.features)

# Split the dataset into a training set (80%) and a test set (20%)
formatted_dataset = formatted_dataset.train_test_split(test_size=0.2, shuffle=True)

# Print an example to verify the format
print("Example of a formatted data sample:")
print(formatted_dataset["train"][0]["messages"])

# 5. LOAD MODEL AND TOKENIZER
# ---------------------------
# Load the pre-trained model and tokenizer from Hugging Face.
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    torch_dtype="auto", # Automatically selects the best data type (bfloat16 on modern GPUs)
    device_map="auto",
    attn_implementation="eager" # Use eager attention mechanism
)
tokenizer = AutoTokenizer.from_pretrained(base_model)

print(f"Model loaded on device: {model.device}")
print(f"Model data type: {model.dtype}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 63.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires tensorboard~=2.19.0, but you have tensorboard 2.20.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.4/503.4 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.7/564.7 kB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 21.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1968 [00:00<?, ? examples/s]
# Example of a formatted data sample:
# [{'content': 'Explain in simple words: What is the recommended pest management for Cabbage butterfly (Pieris brassicae) in Cabbage/Cauliflower?', 'role': 'user'}, {'content': '**Pest Management for Cabbage butterfly (Pieris brassicae):**\n- **Egg stage:** Use trap crops and spray 5% Neem seed kernel extract / Neem leaf extract solution (100 liter/acre).\n- **Larval stage/ Nymph stage:** Increase the activity of predators/parasitoids, place bird perches @8/acre, and spray Dashparni (6 litres in 200 litres of water).\n- **Pupal stage:** Clean the field after the crop harvesting.\n- **Adult stage:** Install 10 pheromone traps per acre, plant trap crops on the bunds/borders, and spray Neem leaf solution.', 'role': 'assistant'}]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Model loaded on device: cuda:0
# Model data type: torch.bfloat16

# %%
# 6. CONFIGURE THE TRAINING PROCESS
# ---------------------------------
# Use SFTConfig to set up all the training hyperparameters.
sft_config = SFTConfig(
    output_dir=output_dir,
    num_train_epochs=3,
    max_length=512,# Number of times to train on the whole dataset
    per_device_train_batch_size=2,          # Batch size for training
    gradient_accumulation_steps=4,          # Effective batch size will be 4 * 2 = 8
    optim="adamw_torch_fused",              # Use the fused AdamW optimizer for better performance
    logging_steps=1,                        # Log metrics every step
    save_strategy="epoch",                  # Save a model checkpoint at the end of each epoch
    learning_rate=2e-5,                     # The learning rate for the optimizer
    lr_scheduler_type="cosine",
    bf16=True if torch.cuda.is_bf16_supported() else False, # Use bfloat16 precision if available
    fp16=False,
    push_to_hub=False,                      # Set to True to automatically push to Hugging Face Hub
    report_to="tensorboard",                # Log results for visualization in TensorBoard
)

# 7. CREATE AND START THE TRAINER
# -------------------------------
# The SFTTrainer handles the entire training loop.
trainer = SFTTrainer(
    model=model,
    args=sft_config,
    train_dataset=formatted_dataset['train'],
    eval_dataset=formatted_dataset['test'], # Optional: for evaluating loss on a separate set
    processing_class=tokenizer,
)

print("Starting the fine-tuning process...")
# Start the training
trainer.train()

# Save the final model and tokenizer to the specified output directory
trainer.save_model()
print(f"Model successfully saved to {output_dir}")
# Out:
# Starting the fine-tuning process...
#     <div>
#
#       <progress value='64' max='591' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 64/591 05:36 < 47:41, 0.18 it/s, Epoch 0.32/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.305900</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.332200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.418600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.820000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.380500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.473800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.669700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.603500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.543500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.697900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.470000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.459300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.408100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.379700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.458800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.555500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.447500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.481200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.556900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.509200</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.799000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.675700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.444900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.478000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.507800</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.559700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.523800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.576100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.487400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.424200</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.627000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.495900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.339200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.236100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.321000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.523000</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.384500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.444300</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.342000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.377900</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.326300</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.501600</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.505700</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.392100</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.429600</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.338300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.466300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.289500</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.450600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.401800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.355900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.243700</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.440300</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.272600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.646400</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.439200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.457300</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.426400</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.673300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.611400</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.402500</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.367300</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3872894082.py in <cell line: 0>()
#      32 print("Starting the fine-tuning process...")
#      33 # Start the training
# ---> 34 trainer.train()
#      35
#      36 # Save the final model and tokenizer to the specified output directory
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326                 hf_hub_utils.enable_progress_bars()
#    2327         else:
# -> 2328             return inner_training_loop(
#    2329                 args=args,
#    2330                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2670                     )
#    2671                     with context():
# -> 2672                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2673
#    2674                     if (
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/sft_trainer.py in training_step(self, *args, **kwargs)
#    1187     def training_step(self, *args, **kwargs):
#    1188         with self.maybe_activation_offload_context:
# -> 1189             return super().training_step(*args, **kwargs)
#    1190
#    1191     def log(self, logs: dict[str, float], start_time: Optional[float] = None) -> None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in training_step(***failed resolving arguments***)
#    4058                     kwargs["scale_wrt_gas"] = False
#    4059
# -> 4060                 self.accelerator.backward(loss, **kwargs)
#    4061
#    4062             return loss.detach()
#
# /usr/local/lib/python3.12/dist-packages/accelerate/accelerator.py in backward(self, loss, **kwargs)
#    2732             self.lomo_backward(loss, learning_rate)
#    2733         else:
# -> 2734             loss.backward(**kwargs)
#    2735
#    2736     def set_trigger(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     827         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828     try:
# --> 829         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830             t_outputs, *args, **kwargs
#     831         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# 8. TEST THE FINE-TUNED MODEL
# ----------------------------
print("\n--- Testing the Fine-Tuned Model ---")

# Load the fine-tuned model and tokenizer for inference
pipe = pipeline("text-generation", model=output_dir, tokenizer=tokenizer)

while True:
    # Take user input
    question = input("\nEnter your question (or type 'exit' to quit): ").strip()

    # Exit condition
    if question.lower() == "exit":
        print("Exiting...")
        break

    # Format the question into a prompt using the model's chat template
    test_messages = [{"role": "user", "content": question}]
    prompt = pipe.tokenizer.apply_chat_template(test_messages, tokenize=False, add_generation_prompt=True)

    # Generate the answer
    outputs = pipe(prompt, max_new_tokens=256)

    # Print the generated answer
    print(f"\nGenerated Answer:\n{outputs[0]['generated_text'][len(prompt):].strip()}")
# Out:
# Device set to use cuda:0
# --- Testing the Fine-Tuned Model ---
#
# Enter your question (or type 'exit' to quit): what is natural farming?
#
# Generated Answer:
# Natural farming is a chemical-free agricultural approach that uses natural farming methods to grow crops. It is practiced in India, but is gaining popularity worldwide.
#
# Enter your question (or type 'exit' to quit): what is Neemashtra?
#
# Generated Answer:
# Neemashtra is a traditional farming practice from Rajasthan, India where a portion of the field is left fallow for two seasons in a row before sowing the main crop. The land between the two sowing periods is tilled in the summer. This practice is believed to improve soil health by enhancing microbial activity and nutrient cycling.
#
# Enter your question (or type 'exit' to quit): what are Principles of Natural Farming ?
#
# Generated Answer:
# The principles of Natural Farming are based on recognizing the interdependence of soil, microbiome, plants, animals, climate, and human ecology. The practices are designed to work together to create a sustainable and productive farming system.
#
# Enter your question (or type 'exit' to quit): what are the 9 principles of natural farming?
#
# Generated Answer:
# The 9 principles of natural farming are:
# 1. Increased organic matter in the soil
# 2. Minimum tillage
# 3. Diversified cropping systems
# 4. Round-the-Year Soil Cover (365 Days Soil Cover)
# 5. Integration of livestock
# 6. Use of On-farm made natural farming bio-inputs
# 7. Pest management through natural farming methods
# 8. Use of beejamrut
# 9. Use of locally adapted seeds
#
# Enter your question (or type 'exit' to quit): Benefits of increasing Organic Matter in Soil ?
#
# Generated Answer:
# Increasing organic matter in soil offers several benefits:
# - **Increases Soil Biological Life:** It serves as feed for beneficial microbes like bacteria and fungi, which improves nutrient cycling and disease suppression.
# - **Enhances Soil Fertility:** It supports the growth of earthworms, improving soil structure and nutrient cycling.
# - **Improves Soil Moisture Retention:** Organic matter acts like a sponge, retaining water to help plants thrive in dry conditions.
# - **Enhances Crop Productivity:** It improves the plant's capacity for nutrient uptake, leading to better yields.
# - **Sustainable and Climate-Resilient:** It reduces the need for synthetic fertilizers and pesticides, making farming more sustainable and adaptable to changing climatic conditions.
#
# Enter your question (or type 'exit' to quit): types of mulching?
#
# Generated Answer:
# Mulching is a natural practice that involves covering the soil around plants to enhance soil health and manage moisture. There are two main types of mulching:
# 1.  **Soil mulching:** This is the simplest form, involving spreading live or dried biomass (straw, leaves, crop residues) on the soil surface. It serves to protect the soil from erosion, improve fertility as it decomposes, and promotes better soil structure.
# 2.  **Organic mulching:** This category includes materials like compost, manure, and plant residues that are added to the soil to improve fertility, structure, and moisture retention. They enhance soil microbial life, increase nutrient availability, and contribute organic matter upon decomposition, which prevents soil erosion and enhances soil organic carbon.
#
# Enter your question (or type 'exit' to quit): what are the types of mulching
#
# Generated Answer:
# Mulching can be broadly categorized into:
# 1.  **Soil mulching:** This involves adding organic matter to the soil surface to improve its structure, fertility, and moisture-holding capacity. Examples include straw, crop residues, and compost application.
# 2.  **Plant mulching:** This refers to growing plants (cover crops, shrubs, or trees) to cover the soil. Examples are sweet clover, forage grass, and fruit trees.
# 3.  **Organic/Wapsla mulching:** This includes materials like dried cow dung, poultry manure, and crop residues that decompose and enrich the soil.
# 4.  **Living mulch/Biochar mulch:** This is a system where biochar is added to the soil to enhance nutrient cycling and soil health.
# 5.  **Plastic mulch:** This is a synthetic material that blocks sunlight and traps heat, used for seed germination or early plant growth.
#
# Enter your question (or type 'exit' to quit): what is Jeevamrut?
#
# Generated Answer:
# Jeevamrut is a fermented microbial culture made from cow dung, cow urine, jaggery, and pulse flour (green gram, black gram, or finger millet). It is an agricultural waste product from the preparation of curd and buttermilk. Its purpose is to enrich the soil with beneficial microbes, which helps in controlling plant pathogens, improving soil fertility, and enhancing crop yields by reducing the incidence of soil-borne diseases.
#
# Enter your question (or type 'exit' to quit): Concoctions (Beejamrut, Jeevamrut and Ghanjeevamut) for active soil  biology?
#
# Generated Answer:
# **A. Concoctions for Active Soil Biology:**
# - **Beejamrut:** Mix 20 liters of water, 5 kg of cow dung, 5 liters of cow urine, and 500 grams of live Indian jaggery in a vessel. Keep it in the shade for 48 hours, stirring regularly. It should be ready in 2-4 days and can be stored for up to 5 days. To use, dissolve 2-3 litres in 200 litres of water and spray.
# - **Jeevamrut:** Mix 10 kg of desi/goats' dung, 10 litres of desi/goats' urine, 1 kg of jaggery, 10 liters of desi/goats' milk, and 100 gm of soil from a healthy, organic farm in a vessel. Ferment this mixture for 48 hours in the shade, stirring twice daily. It is ready in 3-4 days and can be stored for up to 5 days. To use, dissolve 2-3 litres in 200 litres of water.
# - **Ghanjeevamrut:** Mix 2 tonnes of desi/goats
